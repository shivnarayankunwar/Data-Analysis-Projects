# %%
import pandas as pd
import numpy as np

print(np.__version__)
print(pd.__version__)
# Out:
# 1.26.4
# 2.2.3

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from openpyxl) (2.0.0)

# %%
data = pd.read_excel('spam_data.xlsx')
data
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# # Regular Expression

# %%
import re
def keep_special_characters(v2):
    return re.sub(r'[^a-zA-Z0-9\s.,!?]','', v2)

# %%
data['clean_v2'] = data['v2'].astype(str).apply(keep_special_characters)
data
# Out:
#         v1                                                 v2  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                clean_v2
# 0     Go until jurong point, crazy.. Available only ...
# 1                         Ok lar... Joking wif u oni...
# 2     Free entry in 2 a wkly comp to win FA Cup fina...
# 3     U dun say so early hor... U c already then say...
# 4     Nah I dont think he goes to usf, he lives arou...
# ...                                                 ...
# 5567  This is the 2nd time we have tried 2 contact u...
# 5568                Will  b going to esplanade fr home?
# 5569  Pity,  was in mood for that. So...any other su...
# 5570  The guy did some bitching but I acted like id ...
# 5571                         Rofl. Its true to its name
#
# [5572 rows x 3 columns]

# %% [markdown]
# # Normalization

# %%
data['clean_v2'] = data['clean_v2'].str.lower()
data
# Out:
#         v1                                                 v2  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                clean_v2
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i dont think he goes to usf, he lives arou...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will  b going to esplanade fr home?
# 5569  pity,  was in mood for that. so...any other su...
# 5570  the guy did some bitching but i acted like id ...
# 5571                         rofl. its true to its name
#
# [5572 rows x 3 columns]

# %% [markdown]
# # stemming

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
stemmer = PorterStemmer()

# %%
data['clean_v2']
# Out:
# 0       go until jurong point, crazy.. available only ...
# 1                           ok lar... joking wif u oni...
# 2       free entry in 2 a wkly comp to win fa cup fina...
# 3       u dun say so early hor... u c already then say...
# 4       nah i dont think he goes to usf, he lives arou...
#                               ...
# 5567    this is the 2nd time we have tried 2 contact u...
# 5568                  will  b going to esplanade fr home?
# 5569    pity,  was in mood for that. so...any other su...
# 5570    the guy did some bitching but i acted like id ...
# 5571                           rofl. its true to its name
# Name: clean_v2, Length: 5572, dtype: object

# %%
def stemming(v2):
    ps = PorterStemmer()
    words = v2.split() #we use split here because tokenizer has not worked here.anyhow split words.
    stemmed_words = [ps.stem(word) for word in words]
    return ' '.join(stemmed_words)

# %%
data['stemmed_v2'] = data['clean_v2'].apply(stemming)
data
# Out:
#         v1                                                 v2  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                clean_v2  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i dont think he goes to usf, he lives arou...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will  b going to esplanade fr home?
# 5569  pity,  was in mood for that. so...any other su...
# 5570  the guy did some bitching but i acted like id ...
# 5571                         rofl. its true to its name
#
#                                              stemmed_v2
# 0     go until jurong point, crazy.. avail onli in b...
# 1                           ok lar... joke wif u oni...
# 2     free entri in 2 a wkli comp to win fa cup fina...
# 3     u dun say so earli hor... u c alreadi then say...
# 4     nah i dont think he goe to usf, he live around...
# ...                                                 ...
# 5567  thi is the 2nd time we have tri 2 contact u. u...
# 5568                     will b go to esplanad fr home?
# 5569  pity, wa in mood for that. so...ani other sugg...
# 5570  the guy did some bitch but i act like id be in...
# 5571                           rofl. it true to it name
#
# [5572 rows x 4 columns]

# %%
import spacy
print(f"spaCy version: {spacy.__version__}")
# Out:
# spaCy version: 3.7.2

# %%
pip install en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (3.7.1)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from en_core_web_sm) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.8.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (3.1.4)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from spacy<3.8.0,>=3.7.2->en_core_web_sm) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en_core_web_sm) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en_core_web_sm) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en_core_web_sm) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
try:
    nlp = spacy.load("en_core_web_sm")
    print("Model 'en_core_web_sm' is installed and loaded successfully.")
except OSError:
    print("Model 'en_core_web_sm' is not installed.")
# Out:
# Model 'en_core_web_sm' is installed and loaded successfully.

# %% [markdown]
# # Lemmatization

# %%
# Lemmatization using spaCy
def lemmatization_spacy(text):
    doc = nlp(text)
    lemmatized_words = [token.lemma_ for token in doc]
    return ' '.join(lemmatized_words)

data['lemmatized_text_Spicy'] = data['clean_v2'].apply(lemmatization_spacy)
data
# Out:
#         v1                                                 v2  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                clean_v2  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i dont think he goes to usf, he lives arou...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will  b going to esplanade fr home?
# 5569  pity,  was in mood for that. so...any other su...
# 5570  the guy did some bitching but i acted like id ...
# 5571                         rofl. its true to its name
#
#                                              stemmed_v2  \
# 0     go until jurong point, crazy.. avail onli in b...
# 1                           ok lar... joke wif u oni...
# 2     free entri in 2 a wkli comp to win fa cup fina...
# 3     u dun say so earli hor... u c alreadi then say...
# 4     nah i dont think he goe to usf, he live around...
# ...                                                 ...
# 5567  thi is the 2nd time we have tri 2 contact u. u...
# 5568                     will b go to esplanad fr home?
# 5569  pity, wa in mood for that. so...ani other sugg...
# 5570  the guy did some bitch but i act like id be in...
# 5571                           rofl. it true to it name
#
#                                   lemmatized_text_Spicy
# 0     go until jurong point , crazy .. available onl...
# 1                         ok lar ... joke wif u oni ...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor ... u c already then sa...
# 4     nah I do not think he go to usf , he live arou...
# ...                                                 ...
# 5567  this be the 2nd time we have try 2 contact u. ...
# 5568                 will   b go to esplanade fr home ?
# 5569  pity ,   be in mood for that . so ... any othe...
# 5570  the guy do some bitching but I act like i d be...
# 5571                        rofl . its true to its name
#
# [5572 rows x 5 columns]

# %% [markdown]
# # TOkenization

# %%
 pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\nlp_env\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize


text = "This is a test sentence."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'test', 'sentence', '.']

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# Example text
text = "Natural Language Processing with Python is amazing!"

# Tokenize the text
tokens = word_tokenize(text)
sentences = sent_tokenize(text)

print("Word Tokens:", tokens)
print("Sentence Tokens:", sentences)
# Out:
# Word Tokens: ['Natural', 'Language', 'Processing', 'with', 'Python', 'is', 'amazing', '!']
# Sentence Tokens: ['Natural Language Processing with Python is amazing!']

# %%
from nltk.tokenize import word_tokenize

def tokenize_text(clean_v2):
    return word_tokenize(clean_v2) #word tokenize

def segment_sentences(clean_v2):
    return sent_tokenize(clean_text)


data['tokens'] = data['clean_v2'].apply(tokenize_text)
data
# Out:
#         v1                                                 v2  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                clean_v2  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i dont think he goes to usf, he lives arou...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will  b going to esplanade fr home?
# 5569  pity,  was in mood for that. so...any other su...
# 5570  the guy did some bitching but i acted like id ...
# 5571                         rofl. its true to its name
#
#                                              stemmed_v2  \
# 0     go until jurong point, crazy.. avail onli in b...
# 1                           ok lar... joke wif u oni...
# 2     free entri in 2 a wkli comp to win fa cup fina...
# 3     u dun say so earli hor... u c alreadi then say...
# 4     nah i dont think he goe to usf, he live around...
# ...                                                 ...
# 5567  thi is the 2nd time we have tri 2 contact u. u...
# 5568                     will b go to esplanad fr home?
# 5569  pity, wa in mood for that. so...ani other sugg...
# 5570  the guy did some bitch but i act like id be in...
# 5571                           rofl. it true to it name
#
#                                   lemmatized_text_Spicy  \
# 0     go until jurong point , crazy .. available onl...
# 1                         ok lar ... joke wif u oni ...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor ... u c already then sa...
# 4     nah I do not think he go to usf , he live arou...
# ...                                                 ...
# 5567  this be the 2nd time we have try 2 contact u. ...
# 5568                 will   b go to esplanade fr home ?
# 5569  pity ,   be in mood for that . so ... any othe...
# 5570  the guy do some bitching but I act like i d be...
# 5571                        rofl . its true to its name
#
#                                                  tokens
# 0     [go, until, jurong, point, ,, crazy, .., avail...
# 1              [ok, lar, ..., joking, wif, u, oni, ...]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, ..., u, c, alrea...
# 4     [nah, i, dont, think, he, goes, to, usf, ,, he...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, b, going, to, esplanade, fr, home, ?]
# 5569  [pity, ,, was, in, mood, for, that, ., so, ......
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                [rofl, ., its, true, to, its, name]
#
# [5572 rows x 6 columns]
